# %% [markdown]
# # Read Excel File and Perform Various Activities on File

# %%
#Read a local File

import xlrd
location = ("E:\Development\PIAIC\OpenDataPakistan\public-census_oct_2018.xlsx")
workBook = xlrd.open_workbook(location)
sheet = workBook.sheet_by_index(0)
sheet.cell_value(0,0)

#File Name

print("Sheet Name is: ", workBook.sheet_names(),end='')
print('\n')

#number of rows

print("Total no of Rows: ", sheet.nrows, end='')
print('\n')

#number of columns

print("Total no of columns: ",sheet.ncols, end='')
print('\n')

#columns name

for i in range(sheet.ncols):
    print("Column # ", i,"is: ", sheet.cell_value(0,i), end=',')
    print('\n')

#print column values
colValue = int(input("Please enter column number: "))
for i in range(sheet.nrows):
    print(sheet.cell_value(i,colValue), end='')
    print('\n')

#print row values
rowValue = int(input("Please enter row number: "))
for i in range(sheet.ncols):
    print(sheet.cell_value(rowValue,i), end=',')
# Out:
# Sheet Name is:  ['school']
#
# Total no of Rows:  1231
#
# Total no of columns:  108
#
# Column #  0 is:  school_id,
#
# Column #  1 is:  emiscode,
#
# Column #  2 is:  school_name,
#
# Column #  3 is:  district,
#
# Column #  4 is:  tehsil,
#
# Column #  5 is:  markaz,
#
# Column #  6 is:  moza,
#
# Column #  7 is:  permanent_address,
#
# Column #  8 is:  street_name,
#
# Column #  9 is:  uc_name,
#
# Column #  10 is:  uc_no,
#
# Column #  11 is:  na_no,
#
# Column #  12 is:  pp_no,
#
# Column #  13 is:  head_name,
#
# Column #  14 is:  head_type,
#
# Column #  15 is:  head_grade,
#
# Column #  16 is:  school_status,
#
# Column #  17 is:  medium,
#
# Column #  18 is:  non_func_reason,
#
# Column #  19 is:  school_shift,
#
# Column #  20 is:  school_location,
#
# Column #  21 is:  school_gender,
#
# Column #  22 is:  gender_studying,
#
# Column #  23 is:  school_level,
#
# Column #  24 is:  school_type,
#
# Column #  25 is:  est_year,
#
# Column #  26 is:  upgrade_primary_year,
#
# Column #  27 is:  upgrade_middle_year,
#
# Column #  28 is:  upgrade_high_year,
#
# Column #  29 is:  upgrade_high_sec_year,
#
# Column #  30 is:  bldg_status,
#
# Column #  31 is:  bldg_ownership,
#
# Column #  32 is:  place_status,
#
# Column #  33 is:  construct_type,
#
# Column #  34 is:  bldg_condition,
#
# Column #  35 is:  total_area_kanal,
#
# Column #  36 is:  total_area_marla,
#
# Column #  37 is:  covered_area,
#
# Column #  38 is:  uncovered_area_kanal,
#
# Column #  39 is:  uncovered_area_marla,
#
# Column #  40 is:  total_rooms,
#
# Column #  41 is:  functional_classrooms,
#
# Column #  42 is:  total_non_classrooms,
#
# Column #  43 is:  dangerous_classrooms,
#
# Column #  44 is:  dangerous_non_classrooms,
#
# Column #  45 is:  under_construction_classrooms,
#
# Column #  46 is:  classes,
#
# Column #  47 is:  sections,
#
# Column #  48 is:  openair_class_sections,
#
# Column #  49 is:  drink_water,
#
# Column #  50 is:  drink_water_type,
#
# Column #  51 is:  drink_water_type_other,
#
# Column #  52 is:  electricity,
#
# Column #  53 is:  no_electricity_reason,
#
# Column #  54 is:  electricity_source,
#
# Column #  55 is:  toilets,
#
# Column #  56 is:  total_toilets,
#
# Column #  57 is:  usable_toilets,
#
# Column #  58 is:  need_repairing_toilets,
#
# Column #  59 is:  teachers_toilets,
#
# Column #  60 is:  boundary_wall,
#
# Column #  61 is:  boundary_wall_state,
#
# Column #  62 is:  main_gate,
#
# Column #  63 is:  sewerage,
#
# Column #  64 is:  play_ground,
#
# Column #  65 is:  security,
#
# Column #  66 is:  cricket,
#
# Column #  67 is:  football,
#
# Column #  68 is:  hockey,
#
# Column #  69 is:  badminton,
#
# Column #  70 is:  volleyball,
#
# Column #  71 is:  table_tennis,
#
# Column #  72 is:  other,
#
# Column #  73 is:  teachers_with_furniture,
#
# Column #  74 is:  students_with_furniture,
#
# Column #  75 is:  csl_council_meetings,
#
# Column #  76 is:  csl_total_council_members,
#
# Column #  77 is:  csl_council_members_male,
#
# Column #  78 is:  csl_council_members_female,
#
# Column #  79 is:  csl_council_category_parents,
#
# Column #  80 is:  csl_council_category_teachers,
#
# Column #  81 is:  csl_council_category_general,
#
# Column #  82 is:  library,
#
# Column #  83 is:  library_condition,
#
# Column #  84 is:  total_books,
#
# Column #  85 is:  science_lab,
#
# Column #  86 is:  physics_lab,
#
# Column #  87 is:  physics_appratus,
#
# Column #  88 is:  biology_lab,
#
# Column #  89 is:  biology_appratus,
#
# Column #  90 is:  chemistry_lab,
#
# Column #  91 is:  chemistry_appratus,
#
# Column #  92 is:  home_economic_lab,
#
# Column #  93 is:  home_economic_appratus,
#
# Column #  94 is:  combine_lab,
#
# Column #  95 is:  combine_appratus,
#
# Column #  96 is:  computer_lab,
#
# Column #  97 is:  total_computers,
#
# Column #  98 is:  total_computer_training_students,
#
# Column #  99 is:  internet,
#
# Column #  100 is:  ece_room,
#
# Column #  101 is:  ece_room_under_construction,
#
# Column #  102 is:  ece_equipments,
#
# Column #  103 is:  ece_trained_teachers,
#
# Column #  104 is:  care_giver,
#
# Column #  105 is:  enrollment,
#
# Column #  106 is:  Teachers,
#
# Column #  107 is:  NonTeachers,
#
# Please enter column number: 34
# bldg_condition
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Partial Building is Dangerous
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Building Is Dangerous
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Building Is Dangerous
#
# Satisfying
#
# Partial Building is Dangerous
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Partial Building is Dangerous
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Building Is Dangerous
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Complete Building Needs Repairing
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Partial Building is Dangerous
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Satisfying
#
# Needed Minor Repairing
#
# Satisfying
#
# Please enter row number: 23
# 20898,34120035.0,GGHS DHAUNKAL,GUJRANWALA,WAZIRABAD,SECONDARY-WING,DHOUNKAL,VPO DHOUNKAL WAZIRABAD GUJRANWALA,DHOUNKAL,DHOUNKAL,3,79,51,NASREEN AKHTER,Permanent,18,Functional,English,,Morning,Rural,Female,Both,High,Pilot Secondary,1933,1933,1963,1985,0,1,Education Department,1,Completely Solid,Partial Building is Dangerous,14,18,28288,9,14,19,15,2,2,0,0,11,16,2,1,Water Pump,,1,,Wapda connection,1,12,10,2,2,1,Completed,1,1,0,Satisfying,0,0,0,1,0,0,0,15,690,10,11,2,9,5,2,4,0,,NULL,0,,,,,,,,,,,1,16,20,1,1,0,1,1,1,679.0,27.0,7.0,
